# %% [markdown]
# About the Dataset:
#
# 1. id: unique id for a news article
# 2. title: the title of a news article
# 3. author: author of the news article
# 4. text: the text of the article; could be incomplete
# 5. label: a label that marks whether the news article is real or fake:
#            1: Fake news
#            0: real News

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
import re
import numpy as np
import itertools
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# printing the stopwords in English
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# Data Pre-processing

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/My Drive/fakenews
# Out:
# /content/gdrive/My Drive/fakenews

# %%
# loading the dataset to a pandas DataFrame
news_dataset = pd.read_csv('train.csv')

# %%
news_dataset.shape
# Out:
# (20800, 5)

# %%
# print the first 5 rows of the dataframe
news_dataset.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
# counting the number of missing values in the dataset
news_dataset.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
# replacing the null values with empty string
news_dataset = news_dataset.fillna('')

# %%
# merging the author name and news title
news_dataset['content'] = news_dataset['author']+' '+news_dataset['title']

# %%
print(news_dataset['content'])
# Out:
# 0        Darrell Lucus House Dem Aide: We Didn’t Even S...
# 1        Daniel J. Flynn FLYNN: Hillary Clinton, Big Wo...
# 2        Consortiumnews.com Why the Truth Might Get You...
# 3        Jessica Purkiss 15 Civilians Killed In Single ...
# 4        Howard Portnoy Iranian woman jailed for fictio...
#                                ...
# 20795    Jerome Hudson Rapper T.I.: Trump a ’Poster Chi...
# 20796    Benjamin Hoffman N.F.L. Playoffs: Schedule, Ma...
# 20797    Michael J. de la Merced and Rachel Abrams Macy...
# 20798    Alex Ansary NATO, Russia To Hold Parallel Exer...
# 20799              David Swanson What Keeps the F-35 Alive
# Name: content, Length: 20800, dtype: object

# %%
# separating the data & label
X = news_dataset.drop(columns='label', axis=1)
Y = news_dataset['label']

# %%
news_dataset = news_dataset.dropna()
news_dataset2 = news_dataset.copy()

# %%
news_dataset2.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              content
# 0  Darrell Lucus House Dem Aide: We Didn’t Even S...
# 1  Daniel J. Flynn FLYNN: Hillary Clinton, Big Wo...
# 2  Consortiumnews.com Why the Truth Might Get You...
# 3  Jessica Purkiss 15 Civilians Killed In Single ...
# 4  Howard Portnoy Iranian woman jailed for fictio...

# %%
news_dataset2.reset_index(inplace=True)
news_dataset2.head()
# Out:
#    index  id                                              title  \
# 0      0   0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1      1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2      2   2                  Why the Truth Might Get You Fired
# 3      3   3  15 Civilians Killed In Single US Airstrike Hav...
# 4      4   4  Iranian woman jailed for fictional unpublished...
#
#                author                                               text  \
# 0       Darrell Lucus  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1     Daniel J. Flynn  Ever get the feeling your life circles the rou...
# 2  Consortiumnews.com  Why the Truth Might Get You Fired October 29, ...
# 3     Jessica Purkiss  Videos 15 Civilians Killed In Single US Airstr...
# 4      Howard Portnoy  Print \nAn Iranian woman has been sentenced to...
#
#    label                                            content
# 0      1  Darrell Lucus House Dem Aide: We Didn’t Even S...
# 1      0  Daniel J. Flynn FLYNN: Hillary Clinton, Big Wo...
# 2      1  Consortiumnews.com Why the Truth Might Get You...
# 3      1  Jessica Purkiss 15 Civilians Killed In Single ...
# 4      1  Howard Portnoy Iranian woman jailed for fictio...

# %%
news_dataset2['title'][2]
# Out:
# 'Why the Truth Might Get You Fired'

# %%
print(X)
print(Y)
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# 2                             Consortiumnews.com
# 3                                Jessica Purkiss
# 4                                 Howard Portnoy
# ...                                          ...
# 20795                              Jerome Hudson
# 20796                           Benjamin Hoffman
# 20797  Michael J. de la Merced and Rachel Abrams
# 20798                                Alex Ansary
# 20799                              David Swanson
#
#                                                     text  \
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...
# 1      Ever get the feeling your life circles the rou...
# 2      Why the Truth Might Get You Fired October 29, ...
# 3      Videos 15 Civilians Killed In Single US Airstr...
# 4      Print \nAn Iranian woman has been sentenced to...
# ...                                                  ...
# 20795  Rapper T. I. unloaded on black celebrities who...
# 20796  When the Green Bay Packers lost to the Washing...
# 20797  The Macy’s of today grew from the union of sev...
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799    David Swanson is an author, activist, journa...
#
#                                                  content
# 0      Darrell Lucus House Dem Aide: We Didn’t Even S...
# 1      Daniel J. Flynn FLYNN: Hillary Clinton, Big Wo...
# 2      Consortiumnews.com Why the Truth Might Get You...
# 3      Jessica Purkiss 15 Civilians Killed In Single ...
# 4      Howard Portnoy Iranian woman jailed for fictio...
# ...                                                  ...
# 20795  Jerome Hudson Rapper T.I.: Trump a ’Poster Chi...
# 20796  Benjamin Hoffman N.F.L. Playoffs: Schedule, Ma...
# 20797  Michael J. de la Merced and Rachel Abrams Macy...
# 20798  Alex Ansary NATO, Russia To Hold Parallel Exer...
# 20799            David Swanson What Keeps the F-35 Alive
#
# [20800 rows x 5 columns]
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 20795    0
# 20796    0
# 20797    0
# 20798    1
# 20799    1
# Name: label, Length: 20800, dtype: int64

# %% [markdown]
# Stemming:
#
# Stemming is the process of reducing a word to its Root word
#
# example:
# actor, actress, acting --> act

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]',' ',content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)
    return stemmed_content

# %%
news_dataset['content'] = news_dataset['content'].apply(stemming)

# %%
print(news_dataset['content'])
# Out:
# 0        darrel lucu hous dem aid even see comey letter...
# 1        daniel j flynn flynn hillari clinton big woman...
# 2                   consortiumnew com truth might get fire
# 3        jessica purkiss civilian kill singl us airstri...
# 4        howard portnoy iranian woman jail fiction unpu...
#                                ...
# 20795    jerom hudson rapper trump poster child white s...
# 20796    benjamin hoffman n f l playoff schedul matchup...
# 20797    michael j de la merc rachel abram maci said re...
# 20798    alex ansari nato russia hold parallel exercis ...
# 20799                            david swanson keep f aliv
# Name: content, Length: 20800, dtype: object

# %%
#separating the data and label
X = news_dataset['content'].values
Y = news_dataset['label'].values

# %%
print(X)
# Out:
# ['darrel lucu hous dem aid even see comey letter jason chaffetz tweet'
#  'daniel j flynn flynn hillari clinton big woman campu breitbart'
#  'consortiumnew com truth might get fire' ...
#  'michael j de la merc rachel abram maci said receiv takeov approach hudson bay new york time'
#  'alex ansari nato russia hold parallel exercis balkan'
#  'david swanson keep f aliv']

# %%
print(Y)
# Out:
# [1 0 1 ... 0 1 1]

# %%
Y.shape
# Out:
# (20800,)

# %%
# converting the textual data to numerical data
vectorizer = TfidfVectorizer()
vectorizer.fit(X)

X = vectorizer.transform(X)
y = news_dataset2['label']

# %%
print(X)
# Out:
#   (0, 15686)	0.28485063562728646
#   (0, 13473)	0.2565896679337957
#   (0, 8909)	0.3635963806326075
#   (0, 8630)	0.29212514087043684
#   (0, 7692)	0.24785219520671603
#   (0, 7005)	0.21874169089359144
#   (0, 4973)	0.233316966909351
#   (0, 3792)	0.2705332480845492
#   (0, 3600)	0.3598939188262559
#   (0, 2959)	0.2468450128533713
#   (0, 2483)	0.3676519686797209
#   (0, 267)	0.27010124977708766
#   (1, 16799)	0.30071745655510157
#   (1, 6816)	0.1904660198296849
#   (1, 5503)	0.7143299355715573
#   (1, 3568)	0.26373768806048464
#   (1, 2813)	0.19094574062359204
#   (1, 2223)	0.3827320386859759
#   (1, 1894)	0.15521974226349364
#   (1, 1497)	0.2939891562094648
#   (2, 15611)	0.41544962664721613
#   (2, 9620)	0.49351492943649944
#   (2, 5968)	0.3474613386728292
#   (2, 5389)	0.3866530551182615
#   (2, 3103)	0.46097489583229645
#   :	:
#   (20797, 13122)	0.2482526352197606
#   (20797, 12344)	0.27263457663336677
#   (20797, 12138)	0.24778257724396507
#   (20797, 10306)	0.08038079000566466
#   (20797, 9588)	0.174553480255222
#   (20797, 9518)	0.2954204003420313
#   (20797, 8988)	0.36160868928090795
#   (20797, 8364)	0.22322585870464118
#   (20797, 7042)	0.21799048897828688
#   (20797, 3643)	0.21155500613623743
#   (20797, 1287)	0.33538056804139865
#   (20797, 699)	0.30685846079762347
#   (20797, 43)	0.29710241860700626
#   (20798, 13046)	0.22363267488270608
#   (20798, 11052)	0.4460515589182236
#   (20798, 10177)	0.3192496370187028
#   (20798, 6889)	0.32496285694299426
#   (20798, 5032)	0.4083701450239529
#   (20798, 1125)	0.4460515589182236
#   (20798, 588)	0.3112141524638974
#   (20798, 350)	0.28446937819072576
#   (20799, 14852)	0.5677577267055112
#   (20799, 8036)	0.45983893273780013
#   (20799, 3623)	0.37927626273066584
#   (20799, 377)	0.5677577267055112

# %% [markdown]
# Splitting the dataset to training & test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify=Y, random_state=2)

# %% [markdown]
# **Support Vector Machine**

# %%
classifier = svm.SVC(kernel='linear')
classifier.fit(X_train, Y_train)
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.9974158653846154

# %%
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.9913461538461539

# %% [markdown]
# **Logistic Regression**

# %%
lr = LogisticRegression()
lr.fit(X_train, Y_train)
X_train_prediction = lr.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9865985576923076

# %%
X_test_prediction = lr.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9790865384615385

# %% [markdown]
# **Passive Aggresive Classifier**

# %%
model = PassiveAggressiveClassifier(C = 0.5, random_state = 5)
model.fit(X_train, Y_train)
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9999399038461538

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9927884615384616

# %% [markdown]
# Training the Model: Logistic Regression

# %%
model = PassiveAggressiveClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# PassiveAggressiveClassifier()

# %% [markdown]
# Evaluation

# %% [markdown]
# accuracy score

# %%
# accuracy score on the training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  1.0

# %%
# accuracy score on the test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.9932692307692308

# %% [markdown]
# Making a Predictive System

# %%
X_new = X_test[0]

prediction = model.predict(X_new)
print(prediction)

if (prediction[0]==0):
  print('The news is Real')
else:
  print('The news is Fake')
# Out:
# [1]
# The news is Fake

# %%
print(Y_test[0])
# Out:
# 1

# %%
review = re.sub('[^a-zA-Z]', ' ', news_dataset2['text'][60])
review = review.lower()
review = review.split()
    
review = [port_stem.stem(word) for word in review if not word in stopwords.words('english')]
review = ' '.join(review)
review
# Out:
# 'unit state system tax busi mess one thing nearli everyon agre upon current corpor incom tax manag weird trick tax compani higher statutori rate advanc countri collect less money percentag overal economi infinit complic give compani incent borrow much money move oper countri lower tax rate moment tri fix appear arriv hous senat presid soon republican hand agre major tax bill top prioriti kind chang appear like happen may turn big deal particularli tax plan hous republican propos last summer becom core new legisl among washington lobbi shop polici analysi crowd known cash flow tax border adjust easier think substanti rework busi tax sinc corpor incom tax introduc centuri ago could enact big effect tax depart major corpor global financi market aisl local walmart possibl revamp corpor tax code less polit polar debat sure unfold month ahead health care even individu incom tax consequ busi trajectori economi huge basic idea behind b c f use abbrevi taken hold particularli nerdi corner twitter right compani tax base incom gener unit state countless trick corpor account play reduc incom compani report reduc tax burden trick distort economi two prime exampl transfer intellectu properti oversea hold compani engag corpor invers move compani legal headquart countri lower tax moreov interest payment debt current system make appeal take much debt possibl even though increas risk bankruptci downturn come along hous republican approach instead tax corpor incom goe firm domest cash flow money come sale within unit state border minu money goe pay employe buy suppli forth incent play game oversea compani exist exploit tax differ reloc product countri lower tax tax thing sell unit state regardless incom tax one key issu measur incom said alan auerbach economist univers california berkeley lead advoc idea cash flow follow money tax mr auerbach argu could spur busi invest encourag compani reli debt allow compani enjoy tax save capit invest immedi rather depreci time give favor treatment debt oppos equiti alon would amount major shift tax system congression staff member incom administr armi lobbyist spend countless hour hammer detail propos might phase treat financi servic much complex polit problemat element plan revolv around treatment intern trade creat winner loser potenti loser power consid border adjust mean american compani export good new tax system would pay tax intern sale import would tax compani spent make someth sold oversea would pay tax earn compani import good worth abroad sold domest would pay tax full first glanc look would boost export reduc trade deficit inde might prove polit promis advoc strategi pitch plan one would mani economist think work way howev soon tax border adjust look like becom law valu dollar rise currenc market stronger dollar could elimin appar effect tax dollar could rise say percent trade balanc could remain start essenti move system mean bet textbook econom theori analyst evercor isi put becom realiti even though effect test practic dollar strengthen expect exampl industri especi lean profit margin could face disast help explain stiffest opposit tax overhaul come retail industri essenti economist tell trust us model say currenc adjust come wash model wrong compani like walmart target mani other sell larg volum import good viabil could threaten model turn right differ set risk unit state dollar linchpin global financi system larg move valu trigger chang domest tax polici could unforeseen effect mani compani worldwid especi bank especi emerg market debt denomin dollar would becom burden new dollar appreci big dollar rise would also effect shift trillion wealth american invest oversea toward global investor asset unit state jare bernstein center budget polici prioriti note realli know distribut consequ tax overhaul would could increas cost import good poor spend disproportion portion incom like cloth gasolin would bad news poorer american even make overal economi effici still lot work done understand consequ b  ...

# %%
val = vectorizer.transform([review]).toarray()

# %%
model.predict(val)
# Out:
# array([1])

# %% [markdown]
# **Saving the Trained Model and Vectorizer**

# %%
import pickle

# %%
filename = 'model2.pkl'
pickle.dump(model, open(filename, 'wb'))

# %%
pickle.dump(vectorizer, open('tfidfvect2.pkl', 'wb'))

# %% [markdown]
# **Load model and vectorizer to predict the previous datapoint**

# %%
#loading the saved model
loaded_model = pickle.load(open('model2.pkl', 'rb'))

# %%
loaded_vectorizer = pickle.load(open('tfidfvect2.pkl', 'rb'))

# %%
val_pkl = loaded_vectorizer.transform([review]).toarray()

# %%
loaded_model.predict(val_pkl)
# Out:
# array([1])
